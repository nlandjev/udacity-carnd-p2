# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages, which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission if necessary.
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there is a writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) that can be used to guide the writing process. Completing the code template and writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/481/view) for this project.
#
# The [rubric](https://review.udacity.com/#!/rubrics/481/view) contains "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. The stand out suggestions are optional. If you decide to pursue the "stand out suggestions", you can include the code in this Ipython notebook and also discuss the results in the writeup file.
#
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# Load pickled data
import pickle

training_file = 'data/train.p'
validation_file= 'data/valid.p'
testing_file = 'data/test.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below. Use python, numpy and/or pandas methods to calculate the data summary rather than hard coding the results. For example, the [pandas shape method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html) might be useful for calculating some of the summary results.

# %% [markdown]
# ### Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas

# %%
### Replace each question mark with the appropriate value. 
### Use python, pandas or numpy methods rather than hard coding the results

# TODO: Number of training examples
n_train = X_train.shape[0]

# TODO: Number of validation examples
n_validation = X_valid.shape[0]

# TODO: Number of testing examples.
n_test = X_test.shape[0]

# TODO: What's the shape of an traffic sign image?
image_shape = X_train.shape[1:]

# TODO: How many unique classes/labels there are in the dataset.
classes = set(y_train)
n_classes = len(classes)

print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of testing examples = 12630
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections. It can be interesting to look at the distribution of classes in the training, validation and test set. Is the distribution the same? Are there more examples of some classes than others?

# %%
### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline

import random

fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(12, 12))
for row in ax:
    for col in row:
        image = X_train[random.randrange(len(X_train))]
        col.imshow(image)

plt.show()

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!
#
# With the LeNet-5 solution from the lecture, you should expect a validation set accuracy of about 0.89. To meet specifications, the validation set accuracy will need to be at least 0.93. It is possible to get an even higher accuracy, but 0.93 is the minimum for a successful project submission.
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture (is the network over or underfitting?)
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %% [markdown]
# Minimally, the image data should be normalized so that the data has mean zero and equal variance. For image data, `(pixel - 128)/ 128` is a quick way to approximately normalize the data and can be used in this project.
#
# Other pre-processing steps are optional. You can try different techniques to see if it improves performance.
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project.

# %%
### Preprocess the data here. It is required to normalize the data. Other preprocessing steps could include 
### converting to grayscale, etc.
### Feel free to use as many code cells as needed.

import numpy as np

mean = np.mean(X_train, axis=(0, 1, 2))
std = np.std(X_train, axis=(0, 1, 2))

print("Mean: {}, Std Deviation: {}".format(mean, std))
# Out:
# Mean: [86.69812205 79.49594061 81.83870445], Std Deviation: [69.28387882 66.26993615 67.76634548]

# %%
X_train_norm = (X_train.astype(np.float32) - mean) / std
X_valid_norm = (X_valid.astype(np.float32) - mean) / std
X_test_norm = (X_test.astype(np.float32) - mean) / std

# %% [markdown]
# ### Model Architecture

# %%
import tensorflow as tf

print("Using TensorFlow {}".format(tf.__version__))
# Out:
# Using TensorFlow 1.7.0

# %%
def _init_lenet(inputs, training):
    # conv1 layer
    net = tf.layers.conv2d(inputs,
                           filters=6,
                           kernel_size=[5, 5],
                           padding="valid",
                           kernel_initializer=tf.random_normal_initializer(),
                           bias_initializer=tf.random_normal_initializer())
    net = tf.layers.dropout(net, rate=0.2, training=training)
    net = tf.nn.relu(net)
    net = tf.layers.max_pooling2d(net, pool_size=[2, 2], strides=2)
    
    # conv2 layer
    net = tf.layers.conv2d(net,
                           filters=16,
                           kernel_size=[5, 5],
                           padding="valid",
                           kernel_initializer=tf.random_normal_initializer(),
                           bias_initializer=tf.random_normal_initializer())
    net = tf.layers.dropout(net, rate=0.2, training=training)
    net = tf.nn.relu(net)
    net = tf.layers.max_pooling2d(net, pool_size=[2, 2], strides=2)
    
    # flatten
    net = tf.reshape(net, shape=[-1, 5 * 5 * 16])
    
    # fc1 layer
    net = tf.layers.dense(net, 
                          units=120, 
                          kernel_initializer=tf.random_normal_initializer(),
                          bias_initializer=tf.random_normal_initializer())
    net = tf.layers.dropout(net, rate=0.2, training=training)
    net = tf.nn.relu(net)
    
    # fc2 layer
    net = tf.layers.dense(net, 
                          units=84,
                          kernel_initializer=tf.random_normal_initializer(),
                          bias_initializer=tf.random_normal_initializer())
    net = tf.layers.dropout(net, rate=0.2, training=training)
    net = tf.nn.relu(net)
    
    # fc3 layer
    net = tf.layers.dense(net, 
                          units=43,
                          kernel_initializer=tf.random_normal_initializer(),
                          bias_initializer=tf.random_normal_initializer())
    
    return net

def lenet(features, labels, mode):
    logits = _init_lenet(features['x'], 
                         training=(mode == tf.estimator.ModeKeys.TRAIN))
    
    print(logits.shape)
    
    predictions = {
      "classes": tf.argmax(input=logits, axis=1),
      "probabilities": tf.nn.softmax(logits, name="softmax_tensor")
    }

    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)

    loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)

    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.train.AdamOptimizer(learning_rate=1e-3)
        train_op = optimizer.minimize(loss=loss,
                                      global_step=tf.train.get_global_step())
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)

    eval_metric_ops = {
        "accuracy": tf.metrics.accuracy(labels=labels, predictions=predictions["classes"])
    }

    return tf.estimator.EstimatorSpec(mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

# %%
traffic_sign_classifier = tf.estimator.Estimator(model_fn=lenet, model_dir="./traffic-sign-lenet")
logging_hook = tf.train.LoggingTensorHook(tensors={}, every_n_iter=50)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_evaluation_master': '', '_service': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_is_chief': True, '_global_id_in_cluster': 0, '_num_worker_replicas': 1, '_save_checkpoints_steps': None, '_task_type': 'worker', '_log_step_count_steps': 100, '_num_ps_replicas': 0, '_task_id': 0, '_session_config': None, '_model_dir': './traffic-sign-lenet', '_keep_checkpoint_max': 5, '_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f9cf82b3470>, '_tf_random_seed': None, '_keep_checkpoint_every_n_hours': 10000}

# %%
# Train the model
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": X_train_norm.astype(np.float32)},
    y=y_train.astype(np.int32),
    batch_size=128,
    num_epochs=None,
    shuffle=True)
traffic_sign_classifier.train(
    input_fn=train_input_fn,
    steps=20000)
# Out:
# INFO:tensorflow:Calling model_fn.
# (128, 43)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./traffic-sign-lenet/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 20001 into ./traffic-sign-lenet/model.ckpt.
# INFO:tensorflow:loss = 3.5521817, step = 20000
# INFO:tensorflow:global_step/sec: 179.696
# INFO:tensorflow:loss = 3.4826214, step = 20100 (0.558 sec)
# INFO:tensorflow:global_step/sec: 211.152
# INFO:tensorflow:loss = 3.3416407, step = 20200 (0.474 sec)
# INFO:tensorflow:global_step/sec: 197.785
# INFO:tensorflow:loss = 4.286704, step = 20300 (0.505 sec)
# INFO:tensorflow:global_step/sec: 206.977
# INFO:tensorflow:loss = 3.136652, step = 20400 (0.484 sec)
# INFO:tensorflow:global_step/sec: 193.829
# INFO:tensorflow:loss = 3.2164545, step = 20500 (0.516 sec)
# INFO:tensorflow:global_step/sec: 212.773
# INFO:tensorflow:loss = 3.3265743, step = 20600 (0.470 sec)
# INFO:tensorflow:global_step/sec: 201.739
# INFO:tensorflow:loss = 3.4052281, step = 20700 (0.496 sec)
# INFO:tensorflow:global_step/sec: 208.06
# INFO:tensorflow:loss = 3.7230556, step = 20800 (0.480 sec)
# INFO:tensorflow:global_step/sec: 215.86
# INFO:tensorflow:loss = 2.9766946, step = 20900 (0.463 sec)
# INFO:tensorflow:global_step/sec: 212.969
# INFO:tensorflow:loss = 4.5498095, step = 21000 (0.470 sec)
# INFO:tensorflow:global_step/sec: 206.899
# INFO:tensorflow:loss = 3.0326667, step = 21100 (0.483 sec)
# INFO:tensorflow:global_step/sec: 211.433
# INFO:tensorflow:loss = 4.0669413, step = 21200 (0.473 sec)
# INFO:tensorflow:global_step/sec: 185.528
# INFO:tensorflow:loss = 3.055131, step = 21300 (0.539 sec)
# INFO:tensorflow:global_step/sec: 182.359
# INFO:tensorflow:loss = 3.9680042, step = 21400 (0.548 sec)
# INFO:tensorflow:global_step/sec: 202.099
# INFO:tensorflow:loss = 4.1624184, step = 21500 (0.495 sec)
# INFO:tensorflow:global_step/sec: 195.93
# INFO:tensorflow:loss = 3.0797863, step = 21600 (0.510 sec)
# INFO:tensorflow:global_step/sec: 229.965
# INFO:tensorflow:loss = 3.7150388, step = 21700 (0.435 sec)
# INFO:tensorflow:global_step/sec: 235.709
# INFO:tensorflow:loss = 3.245067, step = 21800 (0.424 sec)
# INFO:tensorflow:global_step/sec: 202.228
# INFO:tensorflow:loss = 3.8551521, step = 21900 (0.494 sec)
# INFO:tensorflow:global_step/sec: 228.403
# INFO:tensorflow:loss = 3.1853037, step = 22000 (0.438 sec)
# INFO:tensorflow:global_step/sec: 214.42
# INFO:tensorflow:loss = 3.4093094, step = 22100 (0.467 sec)
# INFO:tensorflow:global_step/sec: 210.692
# INFO:tensorflow:loss = 3.83176, step = 22200 (0.474 sec)
# INFO:tensorflow:global_step/sec: 214.973
# INFO:tensorflow:loss = 3.391409, step = 22300 (0.465 sec)
# INFO:tensorflow:global_step/sec: 223.216
# INFO:tensorflow:loss = 3.118555, step = 22400 (0.448 sec)
# INFO:tensorflow:global_step/sec: 199.987
# INFO:tensorflow:loss = 3.1766305, step = 22500 (0.500 sec)
# INFO:tensorflow:global_step/sec: 186.973
# INFO:tensorflow:loss = 3.4781358, step = 22600 (0.535 sec)
# INFO:tensorflow:global_step/sec: 191.604
# INFO:tensorflow:loss = 3.342259, step = 22700 (0.522 sec)
# INFO:tensorflow:global_step/sec: 183.754
# INFO:tensorflow:loss = 3.012238, step = 22800 (0.544 sec)
# INFO:tensorflow:global_step/sec: 199.974
# INFO:tensorflow:loss = 4.554947, step = 22900 (0.500 sec)
# INFO:tensorflow:global_step/sec: 194.243
# INFO:tensorflow:loss = 3.0501566, step = 23000 (0.515 sec)
# INFO:tensorflow:global_step/sec: 199.54
# INFO:tensorflow:loss = 4.1094885, step = 23100 (0.501 sec)
# INFO:tensorflow:global_step/sec: 193.199
# INFO:tensorflow:loss = 3.1471944, step = 23200 (0.518 sec)
# INFO:tensorflow:global_step/sec: 204.492
# INFO:tensorflow:loss = 4.2478085, step = 23300 (0.488 sec)
# INFO:tensorflow:global_step/sec: 213.29
# INFO:tensorflow:loss = 4.1726913, step = 23400 (0.470 sec)
# INFO:tensorflow:global_step/sec: 180.241
# INFO:tensorflow:loss = 3.1244967, step = 23500 (0.555 sec)
# INFO:tensorflow:global_step/sec: 186.819
# INFO:tensorflow:loss = 3.7288475, step = 23600 (0.536 sec)
# INFO:tensorflow:global_step/sec: 204.914
# INFO:tensorflow:loss = 3.1807365, step = 23700 (0.488 sec)
# INFO:tensorflow:global_step/sec: 200.688
# INFO:tensorflow:loss = 3.675412, step = 23800 (0.498 sec)
# INFO:tensorflow:global_step/sec: 200.777
# INFO:tensorflow:loss = 3.149885, step = 23900 (0.498 sec)
# INFO:tensorflow:global_step/sec: 195.795
# INFO:tensorflow:loss = 3.5639696, step = 24000 (0.511 sec)
# INFO:tensorflow:global_step/sec: 191.521
# INFO:tensorflow:loss = 3.3167584, step = 24100 (0.522 sec)
# INFO:tensorflow:global_step/sec: 200.857
# INFO:tensorflow:loss = 3.4021354, step = 24200 (0.498 sec)
# INFO:tensorflow:global_step/sec: 207.845
# INFO:tensorflow:loss = 3.0065439, step = 24300 (0.481 sec)
# INFO:tensorflow:global_step/sec: 225.247
# INFO:tensorflow:loss = 3.2767808, step = 24400 (0.444 sec)
# INFO:tensorflow:global_step/sec: 198.725
# INFO:tensorflow:loss = 3.787533, step = 24500 (0.504 sec)
# INFO:tensorflow:global_step/sec: 188.887
# INFO:tensorflow:loss = 3.2548923, step = 24600 (0.530 sec)
# INFO:tensorflow:global_step/sec: 179.312
# INFO:tensorflow:loss = 3.189785, step = 24700 (0.558 sec)
# INFO:tensorflow:global_step/sec: 197.51
# INFO:tensorflow:loss = 4.2632523, step = 24800 (0.506 sec)
# INFO:tensorflow:global_step/sec: 229.328
# INFO:tensorflow:loss = 3.1265879, step = 24900 (0.436 sec)
# INFO:tensorflow:global_step/sec: 251.186
# INFO:tensorflow:loss = 3.8913138, step = 25000 (0.398 sec)
# INFO:tensorflow:global_step/sec: 249.199
# INFO:tensorflow:loss = 3.2255704, step = 25100 (0.401 sec)
# INFO:tensorflow:global_step/sec: 225.731
# INFO:tensorflow:loss = 4.2207737, step = 25200 (0.443 sec)
# INFO:tensorflow:global_step/sec: 222.362
# INFO:tensorflow:loss = 3.817249, step = 25300 (0.450 sec)
# INFO:tensorflow:global_step/sec: 191.675
# INFO:tensorflow:loss = 3.1506693, step = 25400 (0.522 sec)
# INFO:tensorflow:global_step/sec: 193.244
# INFO:tensorflow:loss = 3.6928117, step = 25500 (0.517 sec)
# INFO:tensorflow:global_step/sec: 193.108
# INFO:tensorflow:loss = 3.1325176, step = 25600 (0.518 sec)
# INFO:tensorflow:global_step/sec: 193.407
# INFO:tensorflow:loss = 3.647801, step = 25700 (0.517 sec)
# INFO:tensorflow:global_step/sec: 211.832
# INFO:tensorflow:loss = 3.0654535, step = 25800 (0.472 sec)
# INFO:tensorflow:global_step/sec: 236.805
# INFO:tensorflow:loss = 3.9842129, step = 25900 (0.422 sec)
# INFO:tensorflow:global_step/sec: 195.285
# INFO:tensorflow:loss = 3.2346106, step = 26000 (0.513 sec)
# INFO:tensorflow:global_step/sec: 214.427
# INFO:tensorflow:loss = 3.6204078, step = 26100 (0.466 sec)
# INFO:tensorflow:global_step/sec: 210.458
# INFO:tensorflow:loss = 2.9908938, step = 26200 (0.475 sec)
# INFO:tensorflow:global_step/sec: 213.055
# INFO:tensorflow:loss = 3.3306203, step = 26300 (0.470 sec)
# INFO:tensorflow:global_step/sec: 203.986
# INFO:tensorflow:loss = 3.7932153, step = 26400 (0.490 sec)
# INFO:tensorflow:global_step/sec: 198.106
# INFO:tensorflow:loss = 3.0935495, step = 26500 (0.505 sec)
# INFO:tensorflow:global_step/sec: 223.318
# INFO:tensorflow:loss = 3.315189, step = 26600 (0.448 sec)
# INFO:tensorflow:global_step/sec: 204.678
# INFO:tensorflow:loss = 3.7001295, step = 26700 (0.488 sec)
# INFO:tensorflow:global_step/sec: 210.111
# INFO:tensorflow:loss = 3.2257185, step = 26800 (0.476 sec)
# INFO:tensorflow:global_step/sec: 210.011
# INFO:tensorflow:loss = 3.6401072, step = 26900 (0.476 sec)
# INFO:tensorflow:global_step/sec: 218.408
# INFO:tensorflow:loss = 3.2936401, step = 27000 (0.458 sec)
# INFO:tensorflow:global_step/sec: 222.966
# INFO:tensorflow:loss = 4.3902097, step = 27100 (0.448 sec)
# INFO:tensorflow:global_step/sec: 229.926
# INFO:tensorflow:loss = 3.249549, step = 27200 (0.435 sec)
# INFO:tensorflow:global_step/sec: 244.743
# INFO:tensorflow:loss = 3.2155337, step = 27300 (0.409 sec)
# INFO:tensorflow:global_step/sec: 221.398
# INFO:tensorflow:loss = 3.5982003, step = 27400 (0.451 sec)
# INFO:tensorflow:global_step/sec: 246.284
# INFO:tensorflow:loss = 3.2942014, step = 27500 (0.406 sec)
# INFO:tensorflow:global_step/sec: 255.681
# INFO:tensorflow:loss = 3.616224, step = 27600 (0.391 sec)
# INFO:tensorflow:global_step/sec: 241.968
# INFO:tensorflow:loss = 2.9881458, step = 27700 (0.414 sec)
# INFO:tensorflow:global_step/sec: 220.173
# INFO:tensorflow:loss = 4.209897, step = 27800 (0.454 sec)
# INFO:tensorflow:global_step/sec: 252.831
# INFO:tensorflow:loss = 3.158015, step = 27900 (0.395 sec)
# INFO:tensorflow:global_step/sec: 264.165
# INFO:tensorflow:loss = 4.1217995, step = 28000 (0.378 sec)
# INFO:tensorflow:global_step/sec: 241.361
# INFO:tensorflow:loss = 3.0431676, step = 28100 (0.415 sec)
# INFO:tensorflow:global_step/sec: 210.654
# INFO:tensorflow:loss = 3.6836414, step = 28200 (0.475 sec)
# INFO:tensorflow:global_step/sec: 223.302
# INFO:tensorflow:loss = 3.8482242, step = 28300 (0.447 sec)
# INFO:tensorflow:global_step/sec: 198.376
# INFO:tensorflow:loss = 3.0098956, step = 28400 (0.504 sec)
# INFO:tensorflow:global_step/sec: 212.828
# INFO:tensorflow:loss = 3.594648, step = 28500 (0.470 sec)
# INFO:tensorflow:global_step/sec: 210.336
# INFO:tensorflow:loss = 3.328204, step = 28600 (0.476 sec)
# INFO:tensorflow:global_step/sec: 195.562
# INFO:tensorflow:loss = 3.510315, step = 28700 (0.513 sec)
# INFO:tensorflow:global_step/sec: 180.885
# INFO:tensorflow:loss = 3.632388, step = 28800 (0.552 sec)
# INFO:tensorflow:global_step/sec: 205.849
# INFO:tensorflow:loss = 3.3571076, step = 28900 (0.486 sec)
# INFO:tensorflow:global_step/sec: 241.411
# INFO:tensorflow:loss = 4.2376857, step = 29000 (0.414 sec)
# INFO:tensorflow:global_step/sec: 204.674
# INFO:tensorflow:loss = 3.1015491, step = 29100 (0.489 sec)
# INFO:tensorflow:global_step/sec: 191.866
# INFO:tensorflow:loss = 3.187489, step = 29200 (0.521 sec)
# INFO:tensorflow:global_step/sec: 182.125
# INFO:tensorflow:loss = 3.3488696, step = 29300 (0.549 sec)
# INFO:tensorflow:global_step/sec: 203.152
# INFO:tensorflow:loss = 3.4160137, step = 29400 (0.494 sec)
# INFO:tensorflow:global_step/sec: 183.406
# INFO:tensorflow:loss = 3.897118, step = 29500 (0.544 sec)
# INFO:tensorflow:global_step/sec: 179.055
# INFO:tensorflow:loss = 3.0313668, step = 29600 (0.559 sec)
# INFO:tensorflow:global_step/sec: 204.507
# INFO:tensorflow:loss = 4.4980397, step = 29700 (0.489 sec)
# INFO:tensorflow:global_step/sec: 193.836
# INFO:tensorflow:loss = 3.0788755, step = 29800 (0.516 sec)
# INFO:tensorflow:global_step/sec: 209.35
# INFO:tensorflow:loss = 4.183931, step = 29900 (0.477 sec)
# INFO:tensorflow:global_step/sec: 195.698
# INFO:tensorflow:loss = 3.0656419, step = 30000 (0.511 sec)
# INFO:tensorflow:global_step/sec: 209.032
# INFO:tensorflow:loss = 3.9695816, step = 30100 (0.480 sec)
# INFO:tensorflow:global_step/sec: 201.371
# INFO:tensorflow:loss = 4.115009, step = 30200 (0.495 sec)
# INFO:tensorflow:global_step/sec: 199.583
# INFO:tensorflow:loss = 3.0538087, step = 30300 (0.501 sec)
# INFO:tensorflow:global_step/sec: 225.915
# INFO:tensorflow:loss = 3.6644502, step = 30400 (0.443 sec)
# INFO:tensorflow:global_step/sec: 206.109
# INFO:tensorflow:loss = 3.3114505, step = 30500 (0.486 sec)
# INFO:tensorflow:global_step/sec: 204.633
# INFO:tensorflow:loss = 3.7431726, step = 30600 (0.488 sec)
# INFO:tensorflow:global_step/sec: 210.184
# INFO:tensorflow:loss = 3.1842403, step = 30700 (0.476 sec)
# INFO:tensorflow:global_step/sec: 194.991
# INFO:tensorflow:loss = 3.4500573, step = 30800 (0.513 sec)
# INFO:tensorflow:global_step/sec: 204.318
# INFO:tensorflow:loss = 3.847074, step = 30900 (0.489 sec)
# INFO:tensorflow:global_step/sec: 201.195
# INFO:tensorflow:loss = 3.173523, step = 31000 (0.497 sec)
# INFO:tensorflow:global_step/sec: 188.485
# INFO:tensorflow:loss = 3.1154509, step = 31100 (0.531 sec)
# INFO:tensorflow:global_step/sec: 213.525
# INFO:tensorflow:loss = 3.168727, step = 31200 (0.468 sec)
# INFO:tensorflow:global_step/sec: 244.868
# INFO:tensorflow:loss = 3.7453177, step = 31300 (0.408 sec)
# INFO:tensorflow:global_step/sec: 251.737
# INFO:tensorflow:loss = 3.3725696, step = 31400 (0.398 sec)
# INFO:tensorflow:global_step/sec: 252.164
# INFO:tensorflow:loss = 3.092733, step = 31500 (0.396 sec)
# INFO:tensorflow:global_step/sec: 246.815
# INFO:tensorflow:loss = 4.468054, step = 31600 (0.405 sec)
# INFO:tensorflow:global_step/sec: 221.42
# INFO:tensorflow:loss = 3.0285609, step = 31700 (0.452 sec)
# INFO:tensorflow:global_step/sec: 196.86
# INFO:tensorflow:loss = 4.1136484, step = 31800 (0.508 sec)
# INFO:tensorflow:global_step/sec: 208.298
# INFO:tensorflow:loss = 3.0560853, step = 31900 (0.480 sec)
# INFO:tensorflow:global_step/sec: 187.648
# INFO:tensorflow:loss = 4.1963754, step = 32000 (0.532 sec)
# INFO:tensorflow:global_step/sec: 196.427
# INFO:tensorflow:loss = 4.1268306, step = 32100 (0.508 sec)
# INFO:tensorflow:global_step/sec: 188.295
# INFO:tensorflow:loss = 3.0797858, step = 32200 (0.532 sec)
# INFO:tensorflow:global_step/sec: 210.52
# INFO:tensorflow:loss = 3.6625652, step = 32300 (0.475 sec)
# INFO:tensorflow:global_step/sec: 211.436
# INFO:tensorflow:loss = 3.1478336, step = 32400 (0.473 sec)
# INFO:tensorflow:global_step/sec: 217.496
# INFO:tensorflow:loss = 3.6588311, step = 32500 (0.460 sec)
# INFO:tensorflow:global_step/sec: 226.291
# INFO:tensorflow:loss = 3.1501048, step = 32600 (0.443 sec)
# INFO:tensorflow:global_step/sec: 216.092
# INFO:tensorflow:loss = 3.577782, step = 32700 (0.461 sec)
# INFO:tensorflow:global_step/sec: 237.577
# INFO:tensorflow:loss = 3.4740415, step = 32800 (0.421 sec)
# INFO:tensorflow:global_step/sec: 198.296
# INFO:tensorflow:loss = 3.2741058, step = 32900 (0.505 sec)
# INFO:tensorflow:global_step/sec: 201.544
# INFO:tensorflow:loss = 3.0087967, step = 33000 (0.496 sec)
# INFO:tensorflow:global_step/sec: 200.23
# INFO:tensorflow:loss = 3.2269526, step = 33100 (0.500 sec)
# INFO:tensorflow:global_step/sec: 200.072
# INFO:tensorflow:loss = 3.7601414, step = 33200 (0.500 sec)
# INFO:tensorflow:global_step/sec: 196.379
# INFO:tensorflow:loss = 3.2814937, step = 33300 (0.509 sec)
# INFO:tensorflow:global_step/sec: 191.964
# INFO:tensorflow:loss = 3.179144, step = 33400 (0.521 sec)
# INFO:tensorflow:global_step/sec: 201.163
# INFO:tensorflow:loss = 4.157901, step = 33500 (0.497 sec)
# INFO:tensorflow:global_step/sec: 196.389
# INFO:tensorflow:loss = 3.2961276, step = 33600 (0.509 sec)
# INFO:tensorflow:global_step/sec: 189.545
# INFO:tensorflow:loss = 4.0156164, step = 33700 (0.528 sec)
# INFO:tensorflow:global_step/sec: 195.242
# INFO:tensorflow:loss = 3.1227121, step = 33800 (0.512 sec)
# INFO:tensorflow:global_step/sec: 189.545
# INFO:tensorflow:loss = 4.248031, step = 33900 (0.528 sec)
# INFO:tensorflow:global_step/sec: 214.709
# INFO:tensorflow:loss = 3.7426634, step = 34000 (0.465 sec)
# INFO:tensorflow:global_step/sec: 230.859
# INFO:tensorflow:loss = 3.1452484, step = 34100 (0.433 sec)
# INFO:tensorflow:global_step/sec: 218.787
# INFO:tensorflow:loss = 3.7165723, step = 34200 (0.457 sec)
# INFO:tensorflow:global_step/sec: 216.775
# INFO:tensorflow:loss = 3.213428, step = 34300 (0.462 sec)
# INFO:tensorflow:global_step/sec: 179.727
# INFO:tensorflow:loss = 3.5815835, step = 34400 (0.556 sec)
# INFO:tensorflow:global_step/sec: 219.119
# INFO:tensorflow:loss = 3.0659285, step = 34500 (0.456 sec)
# INFO:tensorflow:global_step/sec: 220.096
# INFO:tensorflow:loss = 3.7417524, step = 34600 (0.455 sec)
# INFO:tensorflow:global_step/sec: 220.542
# INFO:tensorflow:loss = 3.227253, step = 34700 (0.455 sec)
# INFO:tensorflow:global_step/sec: 228.674
# INFO:tensorflow:loss = 3.5654094, step = 34800 (0.435 sec)
# INFO:tensorflow:global_step/sec: 222.333
# INFO:tensorflow:loss = 2.9950182, step = 34900 (0.450 sec)
# INFO:tensorflow:global_step/sec: 209.492
# INFO:tensorflow:loss = 3.4443016, step = 35000 (0.477 sec)
# INFO:tensorflow:global_step/sec: 206.875
# INFO:tensorflow:loss = 3.5729613, step = 35100 (0.484 sec)
# INFO:tensorflow:global_step/sec: 198.036
# INFO:tensorflow:loss = 3.1305132, step = 35200 (0.505 sec)
# INFO:tensorflow:global_step/sec: 196.616
# INFO:tensorflow:loss = 3.312041, step = 35300 (0.508 sec)
# INFO:tensorflow:global_step/sec: 195.197
# INFO:tensorflow:loss = 3.7135801, step = 35400 (0.513 sec)
# INFO:tensorflow:global_step/sec: 186.345
# INFO:tensorflow:loss = 3.33186, step = 35500 (0.536 sec)
# INFO:tensorflow:global_step/sec: 184.446
# INFO:tensorflow:loss = 3.650517, step = 35600 (0.545 sec)
# INFO:tensorflow:global_step/sec: 197.457
# INFO:tensorflow:loss = 3.2446132, step = 35700 (0.504 sec)
# INFO:tensorflow:global_step/sec: 194.056
# INFO:tensorflow:loss = 4.318918, step = 35800 (0.516 sec)
# INFO:tensorflow:global_step/sec: 188.083
# INFO:tensorflow:loss = 3.3435073, step = 35900 (0.532 sec)
# INFO:tensorflow:global_step/sec: 200.198
# INFO:tensorflow:loss = 3.251851, step = 36000 (0.499 sec)
# INFO:tensorflow:global_step/sec: 208.178
# INFO:tensorflow:loss = 3.6362684, step = 36100 (0.480 sec)
# INFO:tensorflow:global_step/sec: 183.054
# INFO:tensorflow:loss = 3.168468, step = 36200 (0.546 sec)
# INFO:tensorflow:global_step/sec: 210.349
# INFO:tensorflow:loss = 3.6713538, step = 36300 (0.475 sec)
# INFO:tensorflow:global_step/sec: 218.065
# INFO:tensorflow:loss = 2.951544, step = 36400 (0.459 sec)
# INFO:tensorflow:global_step/sec: 205.075
# INFO:tensorflow:loss = 4.0897307, step = 36500 (0.489 sec)
# INFO:tensorflow:global_step/sec: 214.855
# INFO:tensorflow:loss = 3.1516228, step = 36600 (0.464 sec)
# INFO:tensorflow:global_step/sec: 213.673
# INFO:tensorflow:loss = 4.0399804, step = 36700 (0.468 sec)
# INFO:tensorflow:global_step/sec: 198.733
# INFO:tensorflow:loss = 3.0115852, step = 36800 (0.503 sec)
# INFO:tensorflow:global_step/sec: 193.457
# INFO:tensorflow:loss = 3.545095, step = 36900 (0.517 sec)
# INFO:tensorflow:global_step/sec: 203.36
# INFO:tensorflow:loss = 3.8946123, step = 37000 (0.491 sec)
# INFO:tensorflow:global_step/sec: 230.555
# INFO:tensorflow:loss = 3.0409312, step = 37100 (0.434 sec)
# INFO:tensorflow:global_step/sec: 201.368
# INFO:tensorflow:loss = 3.5530741, step = 37200 (0.497 sec)
# INFO:tensorflow:global_step/sec: 208.37
# INFO:tensorflow:loss = 3.2820578, step = 37300 (0.480 sec)
# INFO:tensorflow:global_step/sec: 231.478
# INFO:tensorflow:loss = 3.4308538, step = 37400 (0.432 sec)
# INFO:tensorflow:global_step/sec: 258.79
# INFO:tensorflow:loss = 3.6657548, step = 37500 (0.386 sec)
# INFO:tensorflow:global_step/sec: 268.723
# INFO:tensorflow:loss = 3.3366513, step = 37600 (0.372 sec)
# INFO:tensorflow:global_step/sec: 250.513
# INFO:tensorflow:loss = 4.2764215, step = 37700 (0.400 sec)
# INFO:tensorflow:global_step/sec: 239.819
# INFO:tensorflow:loss = 3.0842125, step = 37800 (0.417 sec)
# INFO:tensorflow:global_step/sec: 244.612
# INFO:tensorflow:loss = 3.1909842, step = 37900 (0.409 sec)
# INFO:tensorflow:global_step/sec: 230.733
# INFO:tensorflow:loss = 3.377962, step = 38000 (0.433 sec)
# INFO:tensorflow:global_step/sec: 209.519
# INFO:tensorflow:loss = 3.411779, step = 38100 (0.478 sec)
# INFO:tensorflow:global_step/sec: 208.136
# INFO:tensorflow:loss = 3.6891434, step = 38200 (0.480 sec)
# INFO:tensorflow:global_step/sec: 216.859
# INFO:tensorflow:loss = 2.981218, step = 38300 (0.461 sec)
# INFO:tensorflow:global_step/sec: 190.166
# INFO:tensorflow:loss = 4.391095, step = 38400 (0.527 sec)
# INFO:tensorflow:global_step/sec: 202.25
# INFO:tensorflow:loss = 3.11726, step = 38500 (0.494 sec)
# INFO:tensorflow:global_step/sec: 236.25
# INFO:tensorflow:loss = 4.1552563, step = 38600 (0.423 sec)
# INFO:tensorflow:global_step/sec: 242.368
# INFO:tensorflow:loss = 3.0283036, step = 38700 (0.413 sec)
# INFO:tensorflow:global_step/sec: 181.932
# INFO:tensorflow:loss = 3.8497634, step = 38800 (0.550 sec)
# INFO:tensorflow:global_step/sec: 191.159
# INFO:tensorflow:loss = 4.1256156, step = 38900 (0.523 sec)
# INFO:tensorflow:global_step/sec: 197.311
# INFO:tensorflow:loss = 3.0628781, step = 39000 (0.507 sec)
# INFO:tensorflow:global_step/sec: 212.329
# INFO:tensorflow:loss = 3.676813, step = 39100 (0.471 sec)
# INFO:tensorflow:global_step/sec: 195.595
# INFO:tensorflow:loss = 3.3031223, step = 39200 (0.511 sec)
# INFO:tensorflow:global_step/sec: 202.985
# INFO:tensorflow:loss = 3.7439241, step = 39300 (0.493 sec)
# INFO:tensorflow:global_step/sec: 199.42
# INFO:tensorflow:loss = 3.1800864, step = 39400 (0.502 sec)
# INFO:tensorflow:global_step/sec: 203.986
# INFO:tensorflow:loss = 3.4862256, step = 39500 (0.490 sec)
# INFO:tensorflow:global_step/sec: 203.171
# INFO:tensorflow:loss = 3.9138958, step = 39600 (0.492 sec)
# INFO:tensorflow:global_step/sec: 220.003
# INFO:tensorflow:loss = 3.2177024, step = 39700 (0.455 sec)
# INFO:tensorflow:global_step/sec: 207.873
# INFO:tensorflow:loss = 3.154235, step = 39800 (0.481 sec)
# INFO:tensorflow:global_step/sec: 223.771
# INFO:tensorflow:loss = 3.0915496, step = 39900 (0.446 sec)
# INFO:tensorflow:Saving checkpoints for 40000 into ./traffic-sign-lenet/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.7428863.

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": X_valid_norm.astype(np.float32)},
    y=y_valid.astype(np.int32),
    num_epochs=1,
    shuffle=False)
eval_results = traffic_sign_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)
# Out:
# INFO:tensorflow:Calling model_fn.
# (?, 43)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-01-10:48:30
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./traffic-sign-lenet/model.ckpt-40000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-01-10:48:31
# INFO:tensorflow:Saving dict for global step 40000: accuracy = 0.054421768, global_step = 40000, loss = 3.5498304
# {'loss': 3.5498304, 'accuracy': 0.054421768, 'global_step': 40000}

# %% [markdown]
# ### Train, Validate and Test the Model

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# To give yourself more insight into how your model is working, download at least five pictures of German traffic signs from the web and use your model to predict the traffic sign type.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Load and Output the Images

# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Predict the Sign Type for Each Image

# %%
### Run the predictions here and use the model to output the prediction for each image.
### Make sure to pre-process the images with the same pre-processing pipeline used earlier.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Analyze Performance

# %%
### Calculate the accuracy for these 5 new images. 
### For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate on these new images.

# %% [markdown]
# ### Output Top 5 Softmax Probabilities For Each Image Found on the Web

# %% [markdown]
# For each of the new images, print out the model's softmax probabilities to show the **certainty** of the model's predictions (limit the output to the top 5 probabilities for each image). [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here.
#
# The example below demonstrates how tf.nn.top_k can be used to find the top k predictions for each image.
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example. The values in the array represent predictions. The array contains softmax probabilities for five candidate images with six possible classes. `tf.nn.top_k` is used to choose the three classes with the highest probability:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %%
### Print out the top five softmax probabilities for the predictions on the German traffic sign images found on the web. 
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Project Writeup
#
# Once you have completed the code implementation, document your results in a project writeup using this [template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) as a guide. The writeup can be in a markdown or pdf file.

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.

# %% [markdown]
# ---
#
# ## Step 4 (Optional): Visualize the Neural Network's State with Test Images
#
#  This Section is not required to complete but acts as an additional excersise for understaning the output of a neural network's weights. While neural networks can be a great learning device they are often referred to as a black box. We can understand what the weights of a neural network look like better by plotting their feature maps. After successfully training your neural network you can see what it's feature maps look like by plotting the output of the network's weight layers in response to a test stimuli image. From these plotted feature maps, it's possible to see what characteristics of an image the network finds interesting. For a sign, maybe the inner network feature maps react with high activation to the sign's boundary outline or to the contrast in the sign's painted symbol.
#
#  Provided for you below is the function code that allows you to get the visualization output of any tensorflow weight layer you want. The inputs to the function should be a stimuli image, one used during training or a new one you provided, and then the tensorflow variable name that represents the layer's state during the training process, for instance if you wanted to see what the [LeNet lab's](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) feature maps looked like for it's second convolutional layer you could enter conv2 as the tf_activation variable.
#
# For an example of what feature map outputs look like, check out NVIDIA's results in their paper [End-to-End Deep Learning for Self-Driving Cars](https://devblogs.nvidia.com/parallelforall/deep-learning-self-driving-cars/) in the section Visualization of internal CNN State. NVIDIA was able to show that their network's inner weights had high activations to road boundary lines by comparing feature maps from an image with a clear path to one without. Try experimenting with a similar test to show that your trained network's weights are looking for interesting features, whether it's looking at differences in feature maps from images with or without a sign, or even what feature maps look like in a trained network vs a completely untrained one on the same sign image.
#
# <figure>
#  <img src="visualize_cnn.png" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above)</p>
#  </figcaption>
# </figure>
#  <p></p>

# %%
### Visualize your network's feature maps here.
### Feel free to use as many code cells as needed.

# image_input: the test image being fed into the network to produce the feature maps
# tf_activation: should be a tf variable name used during your training procedure that represents the calculated state of a specific weight layer
# activation_min/max: can be used to view the activation contrast in more detail, by default matplot sets min and max to the actual min and max values of the output
# plt_num: used to plot out multiple different weight feature map sets on the same block, just extend the plt number for each new feature map entry

def outputFeatureMap(image_input, tf_activation, activation_min=-1, activation_max=-1 ,plt_num=1):
    # Here make sure to preprocess your image_input in a way your network expects
    # with size, normalization, ect if needed
    # image_input =
    # Note: x should be the same name as your network's tensorflow data placeholder variable
    # If you get an error tf_activation is not defined it may be having trouble accessing the variable from inside a function
    activation = tf_activation.eval(session=sess,feed_dict={x : image_input})
    featuremaps = activation.shape[3]
    plt.figure(plt_num, figsize=(15,15))
    for featuremap in range(featuremaps):
        plt.subplot(6,8, featuremap+1) # sets the number of feature maps to show on each row and column
        plt.title('FeatureMap ' + str(featuremap)) # displays the feature map number
        if activation_min != -1 & activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin =activation_min, vmax=activation_max, cmap="gray")
        elif activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmax=activation_max, cmap="gray")
        elif activation_min !=-1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin=activation_min, cmap="gray")
        else:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", cmap="gray")
